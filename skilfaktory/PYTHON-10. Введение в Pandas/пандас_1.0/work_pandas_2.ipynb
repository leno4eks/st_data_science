# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd


melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data.head()#выгружаем базу и проверям что все выгрузилось корректно
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0        Yarra   -37.7996    144.9984  Northern Metropolitan           4019
# 1        Yarra   -37.8079    144.9934  Northern Metropolitan           4019
# 2        Yarra   -37.8093    144.9944  Northern Metropolitan           4019
# 3        Yarra   -37.7969    144.9969  Northern Metropolitan           4019
# 4        Yarra   -37.8072    144.9941  Northern Metropolitan           4019
#
#           Coordinates
# 0  -37.7996, 144.9984
# 1  -37.8079, 144.9934
# 2  -37.8093, 144.9944
# 3  -37.7969, 144.9969
# 4  -37.8072, 144.9941
#
# [5 rows x 23 columns]

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
#  17  CouncilArea    12211 non-null  object
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  object
#  21  Propertycount  13580 non-null  int64
#  22  Coordinates    13580 non-null  object
# dtypes: float64(6), int64(8), object(9)
# memory usage: 2.4+ MB

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_df = melb_data.copy()
melb_df.head() # создаем копию базы данных чтобы не повредить базу meld_data
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0        Yarra   -37.7996    144.9984  Northern Metropolitan           4019
# 1        Yarra   -37.8079    144.9934  Northern Metropolitan           4019
# 2        Yarra   -37.8093    144.9944  Northern Metropolitan           4019
# 3        Yarra   -37.7969    144.9969  Northern Metropolitan           4019
# 4        Yarra   -37.8072    144.9941  Northern Metropolitan           4019
#
#           Coordinates
# 0  -37.7996, 144.9984
# 1  -37.8079, 144.9934
# 2  -37.8093, 144.9944
# 3  -37.7969, 144.9969
# 4  -37.8072, 144.9941
#
# [5 rows x 23 columns]

# %% [markdown]
# удаление столбцов  используем метод drop()
#
# labels — порядковые номера или имена столбцов, которые подлежат удалению; если их несколько, то передаётся список;
# axis — ось совершения операции, axis=0 — удаляются строки, axis=1 — удаляются столбцы;
# inplace — если параметр выставлен на True, происходит замена изначального DataFrame на новый, при этом метод ничего не возвращает; если на False — возвращается копия DataFrame, из которой удалены указанные строки (столбцы), при этом первоначальный DataFrame не изменяется; по умолчанию параметр равен False.

# %%
melb_df= melb_df.drop(['index','Coordinates'] , axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0       1970        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1       1900        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2       1900        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3       1970        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4       2014        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0          4019
# 1          4019
# 2          4019
# 3          4019
# 4          4019
#
# [5 rows x 21 columns]

# %% [markdown]
# математические операции со столбцами
# столбцы можно складывать, вычитать, умножать, делить между собой, а также возводить в степень.

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms) #  в переменной total_rooms будем хранить общее количество комнат в здании
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
melb_df['MeanRoomsArea'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsArea']) #MeanRoomsArea, который соответствует средней площади одной комнаты для каждого объекта
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsArea, Length: 13580, dtype: float64

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio']) 
# AreaRatio, коэффициент соотношения площади здания (BuildingArea) и площади участка (Landsize).
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %% [markdown]
# **практика**

# %%
customer_df = pd.DataFrame({
        'number': [0, 1, 2, 3, 4],
        'cust_id': [128, 1201, 9832, 4392, 7472],
        'cust_age': [13, 21, 19, 21, 60],
        'cust_sale': [0, 0, 0.2, 0.15, 0.3],
        'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
        'cust_order': [1400, 14142, 900, 1240, 8430]
    })

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
}) # необходимо рассяитать плотность населения и среднее по плотностям 

((countries_df['population']*1000000)/countries_df['area']).mean()
# Out:
# 84.93080566562001

# %% [markdown]
# **ПРИЗНАКИ ДАТЫ И ВРЕМЕНИ**

# %% [markdown]
# Таким форматом в Pandas является формат datetime, который записывается как YYYY-MM-DD HH: MM: SS, то есть составляющие времени указываются в следующем порядке: год, месяц, день, час, минута, секунда.

# %%
display(melb_df['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object

# %% [markdown]
# Тип данных datetime позволяет с помощью специального аксессора dt выделять составляющие времени из каждого элемента столбца, такие как:
#
# date — дата;
# year, month, day — год, месяц, день;
# time — время;
# hour, minute, second — час, минута, секунда;
# dayofweek — номер дня недели, от 0 до 6, где 0 — понедельник, 6 — воскресенье;
# day_name — название дня недели;
# dayofyear — порядковый день года;
# quarter — квартал (интервал в три месяца).

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int32
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# MonthSale
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: proportion, dtype: float64

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') 
display(delta_days)
# Out:
# 0       337 days
# 1        34 days
# 2       428 days
# 3       428 days
# 4       155 days
#           ...
# 13575   603 days
# 13576   603 days
# 13577   603 days
# 13578   603 days
# 13579   603 days
# Name: Date, Length: 13580, dtype: timedelta64[ns]

# %%
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
melb_df = melb_df.drop('YearBuilt', axis=1) #дропаем столбец с годом постройки и меняем его на возраст задния

# %%
melb_df = melb_data.copy()
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
melb_df['weekdaysale'] = melb_df['Date'].dt.day_name()

weekend_count = len(melb_df[melb_df['weekdaysale'] == 'Saturday'])
weekend_count_i = len(melb_df[melb_df['weekdaysale'] == 'Sunday'])
print(weekend_count + weekend_count_i)
# Out:
# 12822

# %% [markdown]
# **Создание и преобразование столбцов с помощью функций**

# %%
print(melb_df['Address'].nunique())
# 13378
# Out:
# 13378

# %%
print(melb_df['Address'].loc[177])
print(melb_df['Address'].loc[1812])
print(melb_df['Address'].loc[9001])
# 2/119 Railway St N
# 9/400 Dandenong Rd
# 172 Danks St
# Out:
# 2/119 Railway St N
# 9/400 Dandenong Rd
# 172 Danks St

# %%
def get_street_type(address):
# Создаём список географических пометок exclude_list.
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: Address, Length: 13580, dtype: object

# %%
print(street_types.nunique())
display(street_types.value_counts())
# Out:
# 56
# Address
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            321
# Gr            311
# Pde           211
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            53
# Tce            47
# Wy             40
# Avenue         40
# Cct            25
# Hwy            24
# Parade         15
# Boulevard      13
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Gdns            4
# Grn             4
# Fairway         4
# Mews            4
# Crossway        3
# Righi           3
# Victoria        2
# Ridge           2
# Crofts          2
# Esp             2
# Glade           1
# Gra             1
# Ave             1
# Woodland        1
# Outlook         1
# Hts             1
# Highway         1
# Athol           1
# Summit          1
# Grand           1
# Res             1
# Nook            1
# Eyrie           1
# Dell            1
# East            1
# Loop            1
# Grange          1
# Terrace         1
# Cove            1
# Qy              1
# Corso           1
# Name: count, dtype: int64

# %%
popular_stypes =street_types.value_counts().nlargest(10).index
print(popular_stypes)
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object')
# Out:
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object', name='Address')

# %%
melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(melb_df['StreetType'])
print(melb_df['StreetType'].nunique())
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 13575       Cr
# 13576       Dr
# 13577       St
# 13578       St
# 13579       St
# Name: StreetType, Length: 13580, dtype: object
# 11

# %%
melb_df = melb_df.drop('Address', axis=1)
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  int64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  int64
#  21  Coordinates    13580 non-null  object
#  22  weekdaysale    13580 non-null  object
#  23  StreetType     13580 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(8), object(9)
# memory usage: 2.5+ MB

# %%
popular_seller = melb_df['SellerG'].value_counts().nlargest(49).index
# заменяем имена компаний, не попавших в список популярных, на строку 'other'
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_seller else 'other') 

a = melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min()
b = melb_df[melb_df['SellerG'] == 'other']['Price'].min()
print(round(a/b, 1))
# Out:
# 1.3

# %%
melb_df['SellerG']
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes) 
    # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#       Column_Name  Num_Unique            Type
# 0            Type           3          object
# 1          Method           5          object
# 2     weekdaysale           5          object
# 3      Regionname           8          object
# 4        Bathroom           9           int64
# 5           Rooms           9           int64
# 6             Car          11           int64
# 7      StreetType          11          object
# 8         Bedroom          12           int64
# 9     CouncilArea          33          object
# 10        SellerG          50          object
# 11           Date          58  datetime64[ns]
# 12      YearBuilt         144           int64
# 13       Postcode         198           int64
# 14       Distance         202         float64
# 15  Propertycount         311           int64
# 16         Suburb         314          object
# 17   BuildingArea         602         float64
# 18       Landsize        1448         float64
# 19          Price        2204         float64
# 20      Lattitude        6503         float64
# 21     Longtitude        7063         float64
# 22    Coordinates       13097          object
# 23          index       13580           int64

# %% [markdown]
# ТИП ДАННЫХ CATEGORY

# %% [markdown]
# Самый простой способ преобразования столбцов к типу данных category — это использование уже знакомого нам метода astype(), в параметры которого достаточно передать строку 'category'.

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  int64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  int64
#  21  Coordinates    13580 non-null  object
#  22  weekdaysale    13580 non-null  object
#  23  StreetType     13580 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(8), object(9)
# memory usage: 2.5+ MB
# None

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  category
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  category
#  6   SellerG        13580 non-null  category
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  category
#  16  CouncilArea    12211 non-null  category
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  category
#  20  Propertycount  13580 non-null  int64
#  21  Coordinates    13580 non-null  object
#  22  weekdaysale    13580 non-null  category
#  23  StreetType     13580 non-null  category
# dtypes: category(8), datetime64[ns](1), float64(6), int64(7), object(2)
# memory usage: 1.8+ MB
# None

# %% [markdown]
# ПОЛУЧЕНИЕ АТРИБУТОВ CATEGORY
#
# У типа данных category есть свой специальный аксесcор cat, который позволяет получать информацию о своих значениях и преобразовывать их. Например, с помощью атрибута этого аксессора categories мы можем получить список уникальных категорий в столбце Regionname:

# %%
print(melb_df['Regionname'].cat.categories)
# Out:
# Index(['Eastern Metropolitan', 'Eastern Victoria', 'Northern Metropolitan',
#        'Northern Victoria', 'South-Eastern Metropolitan',
#        'Southern Metropolitan', 'Western Metropolitan', 'Western Victoria'],
#       dtype='object')

# %%
display(melb_df['Regionname'].cat.codes)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    4
# 13576    6
# 13577    6
# 13578    6
# 13579    6
# Length: 13580, dtype: int8

# %% [markdown]
# С помощью метода аксессора rename_categories() можно легко переименовать текущие значения категорий. Для этого в данный метод нужно передать словарь, ключи которого — старые имена категорий, а значения — новые.

# %%
melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})
display(melb_df['Type'])
# Out:
# 0        house
# 1        house
# 2        house
# 3        house
# 4        house
#          ...
# 13575    house
# 13576    house
# 13577    house
# 13578    house
# 13579    house
# Name: Type, Length: 13580, dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %% [markdown]
# ПОДВОДНЫЕ КАМНИ
#
# А теперь представим ситуацию, что появилась новая партия домов и теперь мы продаём и квартиры (flat). Создадим объект Series new_houses_types, в котором будем хранить типы зданий новой партии домов. Преобразуем тип new_houses_types в такой же тип, как и у столбца Type в таблице melb_data, и выведем результат на экран:

# %%
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2      NaN
# 3      NaN
# 4    house
# dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %% [markdown]
# На самом деле причина проста: тип данных category хранит только категории, которые были объявлены при его инициализации. При встрече с новой, неизвестной ранее категорией, этот тип превратит её в пустое значение, так как он просто не знает о существовании этой категории.

# %% [markdown]
# Решить эту проблему на самом деле не сложно. Можно добавить категорию flat в столбец Type с помощью метода акссесора cat add_categories(), в который достаточно просто передать имя новой категории:

# %%
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %% [markdown]
# **закрепление знаний**

# %% [markdown]
# Примечание. Добавление новой категории в столбец Type не отразится на самом столбце — текущие категории не изменятся, однако такое преобразование позволит добавлять в таблицу новые данные о домах с новой категорией — flat.
#
# Из данного примера можно сделать вывод, что если набор категорий в столбце жёстко не зафиксирован и может обновляться в процессе работы, то тип category не является подходящим типом данных для этого столбца или необходимо постоянно писать проверки при обновлении таблицы.
#
# Теперь, когда мы рассмотрели основные моменты и нюансы работы с типом данных category, можно сформулировать несколько рекомендаций по его использованию:
#
# 1
# Необязательно каждый раз преобразовывать категориальные данные в тип данных category. Зачастую это делается исключительно для оптимизации работы с большими данными.
#
# 2
# Если набор данных занимает значительный процент используемой оперативной памяти, рассмотрите возможность использования типа category.
#
# 3
# Если у вас очень серьёзные проблемы с производительностью, обратите внимание на использование типа category.
#
# 4
# Если вы решили использовать тип category, будьте осторожны при добавлении новой информации в вашу таблицу. Убедитесь, что вы собрали всю необходимую информацию, произведите предобработку данных и только после этого используйте преобразование типов.

# %% [markdown]
# **

# %% [markdown]
# by — имя или список имён столбцов, по значениям которых производится сортировка.
#
# axis — ось, по которой производится сортировка (0 — строки, 1 — столбцы). По умолчанию сортировка производится по строкам.
#
# ascending — сортировка по возрастанию (от меньшего к большему). По умолчанию параметр выставлен на True, для сортировки по убыванию (от большего к меньшему) необходимо выставить его на False.
#
# ignore_index — создаются ли новые индексы в таблице. По умолчанию выставлен на False и сохраняет индексы изначальной таблицы.
#
# inplace — производится ли замена исходной таблицы на отсортированную. По умолчанию параметр выставлен на False, то есть замены не производится. Чтобы переопределить исходную таблицу на отсортированную, необходимо выставить этот параметр на True.

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#        index          Suburb  Rooms   Type     Price Method        SellerG  \
# 2652    2652       Footscray      1   unit   85000.0     PI        Burnham
# 1805    1805       Caulfield      4  house  131000.0     PI          other
# 7303    7303          Albion      1   unit  145000.0     PI         Biggin
# 1927    1927          Coburg      4  house  145000.0     PI         Jellis
# 7940    7940        Hawthorn      1   unit  160000.0     VB            HAR
# 12666  12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811    8811       Footscray      1   unit  170000.0     PI        Burnham
# 8504    8504  West Footscray      1   unit  185000.0     PI            Jas
# 7293    7293          Albion      1   unit  185000.0      S  hockingstuart
# 7305    7305          Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  ...  BuildingArea  YearBuilt  \
# 2652  2016-09-03       6.4      3011  ...         126.0       2007
# 1805  2017-02-25       8.9      3162  ...         155.0       1920
# 7303  2016-05-28      13.9      3020  ...         126.0       1970
# 1927  2016-06-04       7.8      3058  ...         164.0       1910
# 7940  2017-04-08       4.6      3122  ...         126.0       2009
# 12666 2017-09-16       5.2      3056  ...         126.0       1970
# 8811  2017-07-01       5.1      3011  ...          26.0       2013
# 8504  2017-04-29       8.2      3012  ...         126.0       1970
# 7293  2016-08-22      13.9      3020  ...          43.0       1975
# 7305  2016-07-30      13.9      3020  ...         126.0       1970
#
#        CouncilArea  Lattitude  Longtitude             Regionname  \
# 2652   Maribyrnong  -37.79110   144.89000   Western Metropolitan
# 1805     Glen Eira  -37.88640   145.02420  Southern Metropolitan
# 7303      Brimbank  -37.78330   144.82660   Western Metropolitan
# 1927      Moreland  -37.75550   144.96580  Northern Metropolitan
# 7940    Boroondara  -37.81980   145.03730  Southern Metropolitan
# 12666          NaN  -37.77685   144.95188  Northern Metropolitan
# 8811   Maribyrnong  -37.80141   144.89587   Western Metropolitan
# 8504   Maribyrnong  -37.79800   144.86720   Western Metropolitan
# 7293      Brimbank  -37.78520   144.82720   Western Metropolitan
# 7305      Brimbank  -37.78390   144.82390   Western Metropolitan
#
#       Propertycount           Coordinates  weekdaysale StreetType
# 2652           7570      -37.7911, 144.89     Saturday         St
# 1805           2379    -37.8864, 145.0242     Saturday         St
# 7303           2185    -37.7833, 144.8266     Saturday         St
# 1927          11204    -37.7555, 144.9658     Saturday         Rd
# 7940          11308    -37.8198, 145.0373     Saturday         St
# 12666         11918  -37.77685, 144.95188     Saturday         St
# 8811           7570  -37.80141, 144.89587     Saturday         St
# 8504           5058     -37.798, 144.8672     Saturday         St
# 7293           2185    -37.7852, 144.8272       Monday         Rd
# 7305           2185    -37.7839, 144.8239     Saturday         St
#
# [10 rows x 24 columns]

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#        index          Suburb  Rooms   Type      Price Method    SellerG  \
# 13120  13120    Broadmeadows      3  house   575500.0      S      Barry
# 13240  13240        Mulgrave      4  house  1080000.0      S        Ray
# 13242  13242        Mulgrave      5  house   880000.0     PI      other
# 13243  13243        Mulgrave      3  house   840000.0      S        Ray
# 13244  13244     Murrumbeena      3  house  1321188.0     SP   Woodards
# ...      ...             ...    ...    ...        ...    ...        ...
# 2347    2347        Essendon      3  house   911000.0      S    Rendina
# 1          1      Abbotsford      2  house  1035000.0      S     Biggin
# 4544    4544  Oakleigh South      4  house   876000.0      S     Buxton
# 6184    6184    Surrey Hills      3  house  1205000.0      S  Fletchers
# 6183    6183    Surrey Hills      2   unit   813000.0      S  Fletchers
#
#             Date  Distance  Postcode  ...  BuildingArea  YearBuilt  \
# 13120 2017-09-23      14.0      3047  ...         126.0       1970
# 13240 2017-09-23      18.8      3170  ...         204.0       1980
# 13242 2017-09-23      18.8      3170  ...         126.0       1960
# 13243 2017-09-23      18.8      3170  ...         107.0       1972
# 13244 2017-09-23      10.1      3163  ...         200.0       1945
# ...          ...       ...       ...  ...           ...        ...
# 2347  2016-02-04       8.0      3040  ...          98.0       2008
# 1     2016-02-04       2.5      3067  ...          79.0       1900
# 4544  2016-02-04      14.7      3167  ...         126.0       1970
# 6184  2016-01-28      11.2      3127  ...         126.0       1970
# 6183  2016-01-28      11.2      3127  ...         126.0       1970
#
#          CouncilArea  Lattitude  Longtitude                  Regionname  \
# 13120            NaN  -37.67980   144.90936       Northern Metropolitan
# 13240            NaN  -37.93173   145.19475  South-Eastern Metropolitan
# 13242            NaN  -37.92914   145.17372  South-Eastern Metropolitan
# 13243            NaN  -37.93271   145.17792  South-Eastern Metropolitan
# 13244            NaN  -37.90584   145.07250       Southern Metropolitan
# ...              ...        ...         ...                         ...
# 2347   Moonee Valley  -37.74540   144.89870        Western Metropolitan
# 1              Yarra  -37.80790   144.99340       Northern Metropolitan
# 4544        Kingston  -37.93840   145.08780  South-Eastern Metropolitan
# 6184      Whitehorse  -37.83610   145.10060       Southern Metropolitan
# 6183      Whitehorse  -37.82760   145.10230       Southern Metropolitan
#
#       Propertycount           Coordinates  weekdaysale StreetType
# 13120          4294   -37.6798, 144.90936     Saturday         St
# 13240          7113  -37.93173, 145.19475     Saturday         Ct
# 13242          7113  -37.92914, 145.17372     Saturday         St
# 13243          7113  -37.93271, 145.17792     Saturday         Dr
# 13244          4442   -37.90584, 145.0725     Saturday         St
# ...             ...                   ...          ...        ...
# 2347           9264    -37.7454, 144.8987     Thursday         St
# 1              4019    -37.8079, 144.9934     Thursday         St
# 4544           3692    -37.9384, 145.0878     Thursday         St
# 6184           5457    -37.8361, 145.1006     Thursday         Rd
# 6183           5457    -37.8276, 145.1023     Thursday         Rd
#
# [13580 rows x 24 columns]

# %% [markdown]
# Для сортировки по значениям нескольких столбцов необходимо передать названия этих столбцов в параметр by в виде списка. При этом важно обращать внимание на порядок следования столбцов.

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, [ 'Price','Distance']]
# Out:
#            Price  Distance
# 2652     85000.0       6.4
# 7116    200000.0       7.8
# 5206    220000.0      11.2
# 7240    241000.0       8.2
# 2898    250000.0      13.0
# ...          ...       ...
# 13341  4060000.0       6.3
# 8591   4275000.0       1.5
# 1094   4700000.0      11.2
# 5801   5046000.0       6.1
# 251    5525000.0       6.3
#
# [1358 rows x 2 columns]
