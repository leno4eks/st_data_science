# %% [markdown]
# starttime — время начала поездки (дата, время);
# stoptime — время окончания поездки (дата, время);
# start station id — идентификатор стартовой стоянки;
# start station name — название стартовой стоянки;
# start station latitude, start station longitude — географическая широта и долгота стартовой стоянки;
# end station id — идентификатор конечной стоянки;
# end station name — название конечной стоянки;
# end station latitude, end station longitude — географическая широта и долгота конечной стоянки;
# bikeid — идентификатор велосипеда;
# usertype — тип пользователя (Customer — клиент с подпиской на 24 часа или на три дня, Subscriber — подписчик с годовой арендой велосипеда);
# birth year — год рождения клиента;
# gender — пол клиента (0 — неизвестный, 1 — мужчина, 2 — женщина).

# %%
import pandas as pd
meld_data = pd.read_csv('D:\idi\skilfaktory\PYTHON-10. Введение в Pandas\DATA\citibike-tripdata.csv')
meld_data.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# ...

# %%
meld_df =  meld_data.copy()
meld_df.info()
#meld_df.drop(['index', 'Coordinates'],  axis=1, inplace=True)
#meld_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
display(meld_df.describe(include='object'))
meld_df['usertype'].value_counts(normalize=True)
# Out:
#                        starttime                  stoptime  \
# count                     300000                    300000
# unique                    299836                    299813
# top     2018-09-02 13:59:41.7770  2018-09-04 17:51:07.9110
# freq                           2                         2
#
#                        start station name       end station name    usertype
# count                              299831                 299831      300000
# unique                                759                    765           2
# top     Grand Army Plaza & Central Park S  West St & Chambers St  Subscriber
# freq                                 1928                   1963      232202
# usertype
# Subscriber    0.774007
# Customer      0.225993
# Name: proportion, dtype: float64

# %%
display(meld_df.describe())
# Out:
#        start station id  start station latitude  start station longitude  \
# count     299831.000000           300000.000000            300000.000000
# mean        1695.665665               40.737769               -73.982042
# std         1458.264055                0.031999                 0.020207
# min           72.000000               40.655400               -74.025353
# 25%          387.000000               40.716226               -73.995991
# 50%          519.000000               40.737262               -73.985162
# 75%         3282.000000               40.760683               -73.970416
# max         3705.000000               40.869000               -73.878000
#
#        end station id  end station latitude  end station longitude  \
# count   299831.000000         300000.000000          300000.000000
# mean      1684.624298             40.737294             -73.982330
# std       1457.549589              0.031794               0.020261
# ...

# %%
meld_df[meld_df['gender']==1].shape
# Out:
# (183582, 14)

# %%
meld_df = meld_df.drop(['start station id' ,'end station id'] , axis=1)

# %%
meld_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  birth year               300000 non-null  int64
#  11  gender                   300000 non-null  int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 27.5+ MB

# %%
meld_df['age'] = 2018 - meld_df['birth year']
meld_df.drop(['birth year'], axis=1, inplace=True)
print(meld_df[meld_df['age'] > 60].shape[0])
# Out:
# 11837

# %%
meld_df['trip duration'] =pd.to_datetime(meld_df['stoptime']) - pd.to_datetime(meld_df['starttime'])
print(meld_df['trip duration'][3])
55*60+37
# Out:
# 0 days 00:07:16.837000
# 3337
