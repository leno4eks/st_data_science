# %%
import pandas as pd
joined = pd.read_csv('ratings_movies.csv' , sep=',')

# %%
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %% [markdown]
# **ЗАДАЧИ**

# %% [markdown]
# Создайте в таблице новый признак year_release, который соответствует году выпуска фильма.
# У скольких фильмов не указан год их выпуска?

# %%
joined['year_release'] = joined['title'].apply(get_year_release)
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %%
joined.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0

# %% [markdown]
# какой фильм выпущенный в 1999 году, получил наименьшую среднюю оценку зрителей?
# В качестве ответа запишите название этого фильма без указания года его выпуска.

# %%
joined[joined['year_release'] == 1999.0].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)                  0.5
# Trippin' (1999)                                     1.0
# Chill Factor (1999)                                 1.0
# From Dusk Till Dawn 2: Texas Blood Money (1999)     1.0
# Simon Sez (1999)                                    1.0
#                                                    ...
# Mickey's Once Upon a Christmas (1999)               5.0
# On the Ropes (1999)                                 5.0
# Trailer Park Boys (1999)                            5.0
# Five Senses, The (1999)                             5.0
# George Carlin: You Are All Diseased (1999)          5.0
# Name: rating, Length: 261, dtype: float64

# %% [markdown]
# какое сочетание жанров фильмов (genres), выпущенных в 2010 году, получило наименьшую среднюю оценку (rating)

# %%
joined[joined['year_release'] == 2010].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Comedy|Musical                       5.000000
# Name: rating, Length: 119, dtype: float64

# %% [markdown]
# Какой пользователь (userId) посмотрел наибольшее количество различных (уникальных) комбинаций жанров (genres) фильмов? В качестве ответа запишите идентификатор этого пользователя.

# %%
joined.groupby(by='userId')['genres'].nunique().sort_values()
# Out:
# userId
# 245     13
# 85      13
# 214     13
# 494     15
# 578     15
#       ...
# 474    395
# 380    399
# 448    403
# 414    482
# 599    524
# Name: genres, Length: 610, dtype: int64

# %% [markdown]
# Найдите пользователя, который выставил наименьшее количество оценок, но его средняя оценка фильмам наибольшая.

# %%
joined.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %% [markdown]
# Найдите сочетание жанров (genres) за 2018 год, которое имеет наибольший средний рейтинг (среднее по столбцу rating), и при этом число выставленных ему оценок (количество значений в столбце rating) больше 10.
# Запишите сочетание так же, как оно указано в таблице (через разделитель |, без пробелов).

# %%
serrr = joined[joined['year_release']== 2018]
serrr.groupby('genres')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#                                         count      mean
# genres
# Adventure|Comedy|Fantasy                    1  4.500000
# Adventure|Thriller                          1  4.500000
# Comedy|Fantasy|Sci-Fi                       1  4.500000
# Comedy|Romance                              1  4.500000
# Action|Comedy|Crime|Horror                  1  4.000000
# Action|Crime|Drama|Thriller                 1  4.000000
# Action|Animation                            1  3.500000
# Action|Mystery|Sci-Fi|Thriller              1  3.500000
# Crime|Drama                                 1  3.500000
# Horror|Mystery|Thriller                     1  3.500000
# Sci-Fi|Thriller                             1  3.500000
# Action|Comedy                               1  3.000000
# Adventure|Children|Fantasy|Sci-Fi           1  3.000000
# Action|Crime|Thriller                       1  2.500000
# Comedy|Crime|Drama                          1  2.500000
# Drama|Fantasy|Thriller                      1  2.000000
# ...

# %% [markdown]
# Добавьте в таблицу новый признак year_rating — год выставления оценки. Создайте сводную таблицу, которая иллюстрирует зависимость среднего рейтинга фильма от года выставления оценки и жанра. Выберите верные варианты ответа, исходя из построенной таблицы:

# %%
joined['date'] =pd.to_datetime(joined['date'])
joined['year_rating'] =  joined['date'].dt.year

pivot =joined.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc = 'mean'
).loc[2018].sort_values()
display(pivot)
# Out:
# genres
# Action|Adventure|Comedy|Sci-Fi|IMAX    0.5
# Drama|Romance|War|Western              0.5
# Adventure|Children|Comedy|Sci-Fi       0.5
# Action|Fantasy|Sci-Fi|Thriller|War     0.5
# Action|Fantasy|Sci-Fi|IMAX             0.5
#                                       ...
# Romance|Thriller                       NaN
# Romance|War                            NaN
# Romance|Western                        NaN
# Sci-Fi|Thriller|IMAX                   NaN
# War                                    NaN
# Name: 2018, Length: 951, dtype: float64

# %% [markdown]
# Дано два файла:
#
# orders.csv, содержащий данные о заказах;
# products.csv, содержащий данные о товарах.

# %%
orders = pd.read_csv('orders.csv' , sep=(';'))
orders.head(15)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 0          Принят, ожидается оплата     Нет     Нет      Нет        103
# ...

# %%
products = pd.read_csv('products.csv' ,  sep=';')
products.head(150)
# Out:
#     Product_ID                                   Name  Price CURRENCY
# 0           47                   Шатны Полосатый рейс   2999      RUR
# 1           51               Платье Аленький цветочек   4999      RUR
# 2           53                 Штаны Цветочная Поляна   4999      RUR
# 3           71                    Платье Ночная Жизнь   7999      RUR
# 4           74               Платье Ночная Жизнь XXXL   8999      RUR
# 5           86                     Носки Простые, муж     45      RUR
# 6           91                     Носки Честные, муж     50      RUR
# 7          103                  Носки Подарочные, муж    199      RUR
# 8          104                  Носки Подарочные, жен    249      RUR
# 9          124                   Носки беговые Camino    999      RUR
# 10         137              Гольфы детские Снегурочка     99      RUR
# 11         138               Гольфы детские Питер Пен     99      RUR
# ...

# %%
orders_products = orders.merge(
    products,
    left_on='ID товара',
    right_on= 'Product_ID',
    how = 'left'
)
orders_products
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products.iloc[6]
# Out:
# Дата создания     08.11.2019 08:36:22
# Order ID                            5
# ID Покупателя                       5
# Статус                        Отменён
# Оплачен                           Нет
# Отменен                            Да
# Отгружен                          Нет
# ID товара                         124
# Количество                          1
# Product_ID                      124.0
# Name             Носки беговые Camino
# Price                           999.0
# CURRENCY                          RUR
# Name: 6, dtype: object

# %%
orders_products['summa'] = orders_products['Price'] * orders_products['Количество']
orders_products[orders_products['Оплачен']== 'Да'].groupby('ID Покупателя')['summa'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: summa, dtype: float64
